# %% [markdown]
# # Stock Price Prediction using Continuous data stream and LSTMN

# %% [markdown]
# ## Part 1 - Getting Data

# %%
import pandas as pd
import datetime

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-f2056b08-68fd-4121-b1c5-d2ac4146e350" name="files[]" multiple disabled />
#      <output id="result-f2056b08-68fd-4121-b1c5-d2ac4146e350">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving google.csv to google.csv
# User uploaded file "google.csv" with length 143709 bytes

# %% [markdown]
# ### Getting data for GOOGLE stocks

# %%
df = pd.read_csv("google.csv")

# %%
df.head()
# Out:
#         Date    Open    High     Low   Close   Volume
# 0  30-Jun-17  943.99  945.00  929.61  929.68  2287662
# 1  29-Jun-17  951.35  951.66  929.60  937.82  3206674
# 2  28-Jun-17  950.66  963.24  936.16  961.01  2745568
# 3  27-Jun-17  961.60  967.22  947.09  948.09  2443602
# 4  26-Jun-17  990.00  993.99  970.33  972.09  1517912

# %% [markdown]
# ## Part 2 - Cleaning Data

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('mylib.py','wb').write(src)
import preprocess_data as ppd
import numpy as np
# Out:
#      <input type="file" id="files-163d2fe5-b299-4a2c-a248-b3604d33961b" name="files[]" multiple disabled />
#      <output id="result-163d2fe5-b299-4a2c-a248-b3604d33961b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving preprocess_data.py to preprocess_data.py

# %%
stocks = ppd.remove_data(df)
print(stocks.head())
print("---")
print(stocks.tail())
# Out:
#    Item    Open   Close    Volume
# 0     0   98.80  101.46  15860692
# 1     1  100.77   97.35  13762396
# 2     2   96.82   96.85   8239545
# 3     3   97.72   94.37  10389803
# 4     4   95.42   97.02   9666175
# ---
#       Item    Open   Close   Volume
# 3140  3140  990.00  972.09  1517912
# 3141  3141  961.60  948.09  2443602
# 3142  3142  950.66  961.01  2745568
# 3143  3143  951.35  937.82  3206674
# 3144  3144  943.99  929.68  2287662

# %% [markdown]
# ## Part 3 - Visualizing raw data

# %%
from google.colab import files
src = list(files.upload().values())[0]
open('mylib.py','wb').write(src)
import visualize
# Out:
#      <input type="file" id="files-b4b4db30-d12b-440f-99d8-fc26b1f4cbbf" name="files[]" multiple disabled />
#      <output id="result-b4b4db30-d12b-440f-99d8-fc26b1f4cbbf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving visualize.py to visualize.py

# %%
visualize.plot_basic(stocks)

# %% [markdown]
# ### Normalizing Data using MinMax Scaler

# %%
stocks = ppd.get_normalised_data(stocks)
print(stocks.head())

print("\n")
print("Open   --- mean :", np.mean(stocks['Open']),  "  \t Std: ", np.std(stocks['Open']),  "  \t Max: ", np.max(stocks['Open']),  "  \t Min: ", np.min(stocks['Open']))
print("Close  --- mean :", np.mean(stocks['Close']), "  \t Std: ", np.std(stocks['Close']), "  \t Max: ", np.max(stocks['Close']), "  \t Min: ", np.min(stocks['Close']))
print("Volume --- mean :", np.mean(stocks['Volume']),"  \t Std: ", np.std(stocks['Volume']),"  \t Max: ", np.max(stocks['Volume']),"  \t Min: ", np.min(stocks['Volume']))
# Out:
#    Item      Open     Close    Volume
# 0     0  0.012051  0.015141  0.377248
# 1     1  0.014198  0.010658  0.325644
# 2     2  0.009894  0.010112  0.189820
# 3     3  0.010874  0.007407  0.242701
# 4     4  0.008368  0.010298  0.224905
#
#
# Open   --- mean : 0.32119222938868175   	 Std:  0.23261946808306658   	 Max:  0.9999999999999999   	 Min:  0.0
# Close  --- mean : 0.3215558503465895   	 Std:  0.2328307611248222   	 Max:  1.0   	 Min:  0.0
# Volume --- mean : 0.09061506381049178   	 Std:  0.09535947661989866   	 Max:  0.9999999999999999   	 Min:  0.0
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
visualize.plot_basic(stocks)

# %%
stocks.to_csv('google_preprocessed.csv',index= False)

# %% [markdown]
# ## Part 4 - Implementing Linear regressor for comparison

# %%
import math
import pandas as pd
import numpy as np
from IPython.display import display
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-4dd7de1a-d61c-412e-9394-8f298370f39b" name="files[]" multiple disabled />
#      <output id="result-4dd7de1a-d61c-412e-9394-8f298370f39b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving google_preprocessed.csv to google_preprocessed (1).csv
# User uploaded file "google_preprocessed.csv" with length 200356 bytes

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-bd50f46f-4fc0-4ba1-bf8a-f171a5d7991a" name="files[]" multiple disabled />
#      <output id="result-bd50f46f-4fc0-4ba1-bf8a-f171a5d7991a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving LinearRegressionModel.py to LinearRegressionModel.py
# User uploaded file "LinearRegressionModel.py" with length 1057 bytes

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-ecf15095-9183-4bf8-a3c8-c1f46253c1c8" name="files[]" multiple disabled />
#      <output id="result-ecf15095-9183-4bf8-a3c8-c1f46253c1c8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving stock_data.py to stock_data.py
# User uploaded file "stock_data.py" with length 3869 bytes

# %%
stocks = pd.read_csv('google_preprocessed.csv')
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-08ed08b7-3d88-4ecd-b780-8a9c4aaa743f" name="files[]" multiple disabled />
#      <output id="result-08ed08b7-3d88-4ecd-b780-8a9c4aaa743f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving visualize.py to visualize (2).py
# User uploaded file "visualize.py" with length 2564 bytes

# %%
import visualize as vs
import stock_data as sd
import LinearRegressionModel

stocks = pd.read_csv('google_preprocessed.csv')
display(stocks.head())
# Out:
#    Item      Open     Close    Volume
# 0     0  0.012051  0.015141  0.377248
# 1     1  0.014198  0.010658  0.325644
# 2     2  0.009894  0.010112  0.189820
# 3     3  0.010874  0.007407  0.242701
# 4     4  0.008368  0.010298  0.224905

# %%
X_train, X_test, y_train, y_test, label_range= sd.train_test_split_linear_regression(stocks)

print("x_train", X_train.shape)
print("y_train", y_train.shape)
print("x_test", X_test.shape)
print("y_test", y_test.shape)
# Out:
# x_train (2155, 1)
# y_train (2155, 1)
# x_test (990, 1)
# y_test (990, 1)

# %% [markdown]
# ### Checking predictions by Linear Regression to compare later

# %%
model = LinearRegressionModel.build_model(X_train,y_train)

# %%
predictions = LinearRegressionModel.predict_prices(model,X_test, label_range)

# %% [markdown]
# ### Visualizing results of Linear regressor model

# %%
vs.plot_prediction(y_test,predictions)

# %% [markdown]
# ### Measure accuracy of prediction

# %%
trainScore = mean_squared_error(X_train, y_train)
print('Train Score: %.4f MSE (%.4f RMSE)' % (trainScore, math.sqrt(trainScore)))

testScore = mean_squared_error(predictions, y_test)
print('Test Score: %.8f MSE (%.8f RMSE)' % (testScore, math.sqrt(testScore)))
# Out:
# Train Score: 0.1852 MSE (0.4303 RMSE)
# Test Score: 0.08133781 MSE (0.28519784 RMSE)

# %% [markdown]
# ## Part 5 - LSTM Model

# %%
import math
import pandas as pd
import numpy as np
from IPython.display import display

from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential
from keras.metrics import mean_squared_error
from sklearn.model_selection import StratifiedKFold

from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
import lstm, time #helper libraries

import visualize as vs
import stock_data as sd
import LinearRegressionModel
# Out:
# Using TensorFlow backend.
#      <input type="file" id="files-7a80281e-72da-478b-b5c7-3e217622b23c" name="files[]" multiple disabled />
#      <output id="result-7a80281e-72da-478b-b5c7-3e217622b23c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lstm.py to lstm.py
# User uploaded file "lstm.py" with length 1506 bytes

# %%
stocks = pd.read_csv('google_preprocessed.csv')
stocks_data = stocks.drop(['Item'], axis =1)

display(stocks_data.head())
# Out:
#        Open     Close    Volume
# 0  0.012051  0.015141  0.377248
# 1  0.014198  0.010658  0.325644
# 2  0.009894  0.010112  0.189820
# 3  0.010874  0.007407  0.242701
# 4  0.008368  0.010298  0.224905

# %% [markdown]
# ### Splitting data between train and test

# %%
X_train, X_test,y_train, y_test = sd.train_test_split_lstm(stocks_data, 5)

unroll_length = 50
X_train = sd.unroll(X_train, unroll_length)
X_test = sd.unroll(X_test, unroll_length)
y_train = y_train[-X_train.shape[0]:]
y_test = y_test[-X_test.shape[0]:]

print("x_train", X_train.shape)
print("y_train", y_train.shape)
print("x_test", X_test.shape)
print("y_test", y_test.shape)
# Out:
# x_train (2589, 50, 3)
# y_train (2589,)
# x_test (446, 50, 3)
# y_test (446,)

# %% [markdown]
# ### Building the model

# %%
model = lstm.build_basic_model(input_dim = X_train.shape[-1],output_dim = unroll_length, return_sequences=True)

# Compile the model
start = time.time()
model.compile(loss='mean_squared_error', optimizer='adam')
print('compilation time : ', time.time() - start)
# Out:
# compilation time :  0.03080272674560547

# %%
model.fit(
    X_train,
    y_train,
    epochs=1,
    validation_split=0.05)
# Out:
# Train on 2459 samples, validate on 130 samples
# Epoch 1/1
# 2459/2459 [==============================] - 22s 9ms/step - loss: 0.0037 - val_loss: 2.9946e-04

# %%
predictions = model.predict(X_test)

# %% [markdown]
# ### Plotting results

# %%
vs.plot_lstm_prediction(y_test,predictions)

# %%
trainScore = model.evaluate(X_train, y_train, verbose=0)
print('Train Score: %.8f MSE (%.8f RMSE)' % (trainScore, math.sqrt(trainScore)))

testScore = model.evaluate(X_test, y_test, verbose=0)
print('Test Score: %.8f MSE (%.8f RMSE)' % (testScore, math.sqrt(testScore)))
# Out:
# Train Score: 0.00034889 MSE (0.01867871 RMSE)
# Test Score: 0.00102092 MSE (0.03195184 RMSE)

# %% [markdown]
# ## Part 6 - Improving LSTM Model

# %%
# Set up hyperparameters
batch_size = 100
epochs = 5

# build improved lstm model
model = lstm.build_improved_model( X_train.shape[-1],output_dim = unroll_length, return_sequences=True)

start = time.time()
#final_model.compile(loss='mean_squared_error', optimizer='adam')
model.compile(loss='mean_squared_error', optimizer='adam')
print('compilation time : ', time.time() - start)
# Out:
# compilation time :  0.03199124336242676

# %%
model.fit(X_train, 
          y_train, 
          batch_size=batch_size,
          epochs=epochs,
          verbose=2,
          validation_split=0.05
         )
# Out:
# Train on 2459 samples, validate on 130 samples
# Epoch 1/5
#  - 7s - loss: 0.0111 - val_loss: 0.0019
# Epoch 2/5
#  - 6s - loss: 9.5767e-04 - val_loss: 3.8926e-04
# Epoch 3/5
#  - 6s - loss: 6.8480e-04 - val_loss: 3.3794e-04
# Epoch 4/5
#  - 6s - loss: 6.3167e-04 - val_loss: 5.7742e-04
# Epoch 5/5
#  - 6s - loss: 6.3675e-04 - val_loss: 2.8645e-04

# %% [markdown]
# ### PLotting results

# %%
vs.plot_lstm_prediction(y_test,predictions)
trainScore = model.evaluate(X_train, y_train, verbose=0)
print('Train Score: %.8f MSE (%.8f RMSE)' % (trainScore, math.sqrt(trainScore)))

testScore = model.evaluate(X_test, y_test, verbose=0)
print('Test Score: %.8f MSE (%.8f RMSE)' % (testScore, math.sqrt(testScore)))
# Out:
# Train Score: 0.00032052 MSE (0.01790295 RMSE)
# Test Score: 0.00102408 MSE (0.03200132 RMSE)

# %%
0.03200132-0.01790295
# Out:
# 0.014098369999999999
